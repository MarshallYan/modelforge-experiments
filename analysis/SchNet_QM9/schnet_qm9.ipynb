# %% [markdown]
# # SchNet-QM9 Hyperparameter Grid Search

# %% [markdown]
# ## Load trainings using pure atomic number embedding

# %%
import wandb
import pandas as pd

from analysis.helper import extract_config

api = wandb.Api()
runs = api.runs(
    "modelforge_nnps/schnet_qm9E(-q)_replica",
)
print(f"Found {len(runs)} runs")
summary_list, config_list, name_list = [], [], []

# %%
potential_parameter = runs[0].config["potential_parameter"]

# %%
potential_parameter
# Out:
# "potential_name='SchNet' only_unique_pairs=False core_parameter=CoreParameter(number_of_radial_basis_functions=64, maximum_interaction_radius=0.49999999999999994, number_of_interaction_modules=3, number_of_filters=32, shared_interactions=True, activation_function_parameter=ActivationFunctionConfig(activation_function_name='ShiftedSoftplus', activation_function_arguments=None, activation_function=ShiftedSoftplus()), featurization=Featurization(properties_to_featurize=['atomic_number'], atomic_number=AtomicNumber(maximum_atomic_number=101, number_of_per_atom_features=64), atomic_period=AtomicPeriod(maximum_period=8, number_of_per_period_features=32), atomic_group=AtomicGroup(maximum_group=18, number_of_per_group_features=32)), predicted_properties=['per_atom_energy'], predicted_dim=[1]) postprocessing_parameter=PostProcessingParameter(properties_to_process=['per_atom_energy'], per_atom_energy=PerAtomEnergy(normalize=False, from_atom_to_system_reduction=True, keep_per_atom_property=True), per_atom_charge=PerAtomCharge(conserve=True, conserve_strategy='default'), electrostatic_potential=ElectrostaticPotential(electrostatic_strategy='coulomb', maximum_interaction_radius=0.5), general_postprocessing_operation=GeneralPostProcessingOperation(calculate_molecular_self_energy=True, calculate_atomic_self_energy=False)) potential_seed=-1"

# %%
training_parameter = runs[0].config["training_parameter"]

# %%
training_parameter
# Out:
# "monitor='val/per_system_energy/rmse' number_of_epochs=500 remove_self_energies=True shift_center_of_mass_to_origin=False batch_size=128 lr=0.0005 plot_frequency=1 lr_scheduler=ReduceLROnPlateauConfig(scheduler_name='ReduceLROnPlateau', frequency=1, interval='epoch', monitor='val/per_system_energy/rmse', mode='min', factor=0.5, patience=10, threshold=0.1, threshold_mode='abs', cooldown=15, min_lr=1e-06, eps=1e-08) loss_parameter=LossParameter(loss_components=['per_atom_energy'], weight={'per_atom_energy': 1.0}, target_weight={'per_atom_energy': 1.0}, mixing_steps={'per_atom_energy': 1.0}) early_stopping=EarlyStopping(verbose=True, monitor='val/per_system_energy/rmse', min_delta=0.1, patience=100) splitting_strategy=SplittingStrategy(name='random_record_splitting_strategy', data_split=[0.8, 0.1, 0.1], seed=42) stochastic_weight_averaging=None experiment_logger=ExperimentLogger(logger_name='wandb', tensorboard_configuration=None, wandb_configuration=WandbConfig(save_dir='logs', project='schnet_qm9E(-q)_replica', group='seed: 42', log_model=True, job_type='benchmarking', tags=['number_of_interaction_modules: 3', 'number_of_filters: 32', 'number_of_per_atom_features: 64', '0.1.3+0.gf8c7834.dirty', 'QM9', 'SchNet', 'loss-per_atom_energy'], notes='tunning hyperparameters with given ranges (without system charge input)')) verbose=False log_norm=False limit_train_batches=None limit_val_batches=None limit_test_batches=None profiler=None optimizer=<class 'torch.optim.adamw.AdamW'> min_number_of_epochs=None"

# %%
runs[0].summary
# Out:
# {'_runtime': 6130.438239842, '_step': 2450, '_timestamp': 1742962696.7809372, '_wandb': {'runtime': 6130}, 'epoch': 349, 'epoch_time': 18.022900104522705, 'loss/per_atom_energy/mse': 5.331758975982666, 'loss/per_atom_energy/weight': 1, 'loss/total_loss/mse': 5.331758975982666, 'lr': 9.999999974752427e-07, 'outlier_count/test/108287': 1, 'outlier_count/test/54996': 1, 'outlier_count/test/62751': 1, 'outlier_count/val/101816': 3, 'outlier_count/val/107212': 3, 'outlier_count/val/111220': 1, 'outlier_count/val/124144': 1, 'outlier_count/val/127319': 11, 'outlier_count/val/26000': 310, 'outlier_count/val/33355': 2, 'outlier_count/val/45250': 2, 'outlier_count/val/58089': 1, 'outlier_count/val/58918': 2, 'outlier_count/val/66701': 2, 'outlier_count/val/71426': 331, 'outlier_count/val/72905': 1, 'outlier_count/val/75601': 332, 'outlier_count/val/76351': 4, 'outlier_count/val/85483': 25, 'outlier_count/val/89481': 20, 'outlier_count/val/971': 2, 'test/energy_error_histogram': {'_type': 'image-file', 'format': 'png', 'height': 600, 'path': 'media/images/test/energy_error_histogram_2449_97e0b6acc6357f20bfb5.png', 'sha256': '97e0b6acc6357f20bfb5300d5c8613507882044b173b8de293ddb24ac2cf8905', 'size': 31282, 'width': 800}, 'test/per_system_energy/mae': 6.411189556121826, 'test/per_system_energy/rmse': 9.486845016479492, 'test/regression_plot': {'_type': 'image-file', 'format': 'png', 'height': 480, 'path': 'media/images/test/regression_plot_2448_4092a13c5a13bd9dc6fb.png', 'sha256': '4092a13c5a13bd9dc6fb47e7df106fd79c4748e29190292b7d0e31829fa24ab0', 'size': 33203, 'width': 640}, 'train/energy_error_histogram': {'_type': 'image-file', 'format': 'png', 'height': 600, 'path': 'media/images/train/energy_error_histogram_2442_31acf25c246e6742ad6e.png', 'sha256': '31acf25c246e6742ad6e5900121ea62b81096c8f8c3e2346da019258c3b36759', 'size': 29428, 'width': 800}, 'train/regression_plot': {'_type': 'image-file', 'format': 'png', 'height': 480, 'path': 'media/images/train/regression_plot_2441_bfd84365346204b05948.png', 'sha256': 'bfd84365346204b059482568bc845de04e9a451d2ec54d6228e11d5e1f807905', 'size': 34573, 'width': 640}, 'trainer/global_step': 292113, 'val/energy_error_histogram': {'_type': 'image-file', 'format': 'png', 'height': 600, 'path': 'media/images/val/energy_error_histogram_2446_dd823fd9da3b7017b592.png', 'sha256': 'dd823fd9da3b7017b592f14649243b7e5f6838025d7e6b57debe1e86a301ae1f', 'size': 29106, 'width': 800}, 'val/per_system_energy/mae': 6.413447380065918, 'val/per_system_energy/rmse': 9.610507011413574, 'val/regression_plot': {'_type': 'image-file', 'format': 'png', 'height': 480, 'path': 'media/images/val/regression_plot_2445_f510ad3e16cd87a4505b.png', 'sha256': 'f510ad3e16cd87a4505bf1996fdc2aaf72b6b4ea94d820f28a3f3b6af5061a3c', 'size': 33771, 'width': 640}}

# %%
runs[0].config
# Out:
# {'potential_seed': None,
#  'optimizer_class': 'AdamW',
#  'dataset_statistic': {'atomic_self_energies': {'C': '-99366.70745535441 kilojoule_per_mole',
#    'F': '-261811.54555874597 kilojoule_per_mole',
#    'H': '-1313.4668615546 kilojoule_per_mole',
#    'N': '-143309.9379722722 kilojoule_per_mole',
#    'O': '-197082.0671774158 kilojoule_per_mole'},
#   'training_dataset_statistics': {'per_atom_energy_mean': '-409.48571973637587 kilojoule_per_mole',
#    'per_atom_energy_stddev': '18.292824647215742 kilojoule_per_mole'}},
#  'training_parameter': "monitor='val/per_system_energy/rmse' number_of_epochs=500 remove_self_energies=True shift_center_of_mass_to_origin=False batch_size=128 lr=0.0005 plot_frequency=1 lr_scheduler=ReduceLROnPlateauConfig(scheduler_name='ReduceLROnPlateau', frequency=1, interval='epoch', monitor='val/per_system_energy/rmse', mode='min', factor=0.5, patience=10, threshold=0.1, threshold_mode='abs', cooldown=15, min_lr=1e-06, eps=1e-08) loss_parameter=LossParameter(loss_components=['per_atom_energy'], weight={'per_atom_energy': 1.0}, target_weight={'per_atom_energy': 1.0}, mixing_steps={'per_atom_energy': 1.0}) early_stopping=EarlyStopping(verbose=True, monitor='val/per_system_energy/rmse', min_delta=0.1, patience=100) splitting_strategy=SplittingStrategy(name='random_record_splitting_strategy', data_split=[0.8, 0.1, 0.1], seed=42) stochastic_weight_averaging=None experiment_logger=ExperimentLogger(logger_name='wandb', tensorboard_configuration=None, wandb_configuration=WandbConfig(save_dir='logs', project='schnet_qm9E(-q)_replica', group='seed: 42', log_model=True, job_type='benchmarking', tags=['number_of_interaction_modules: 3', 'number_of_filters: 32', 'number_of_per_atom_features: 64', '0.1.3+0.gf8c7834.dirty', 'QM9', 'SchNet', 'loss-per_atom_energy'], notes='tunning hyperparameters with given ranges (without system charge input)')) verbose=False log_norm=False limit_train_batches=None limit_val_batches=None limit_test_batches=None profiler=None optimizer=<class 'torch.optim.adamw.AdamW'> min_number_of_epochs=None",
#  'potential_parameter': "potential_name='SchNet' only_unique_pairs=False core_parameter=CoreParameter(number_of_radial_basis_functions=64, maximum_interaction_radius=0.49999999999999994, number_of_interaction_modules=3, number_of_filters=32, shared_interactions=True, activation_function_parameter=ActivationFunctionConfig(activation_function_name='ShiftedSoftplus', activation_function_arguments=None, activation_function=ShiftedSoftplus()), featurization=Featurization(properties_to_featurize=['atomic_number'], atomic_number=AtomicNumber(maximum_atomic_number=101, number_of_per_atom_features=64), atomic_period=AtomicPeriod(maximum_period=8, number_of_per_period_features=32), atomic_group=AtomicGroup(maximum_group=18, number_of_per_group_features=32)), predicted_properties=['per_atom_energy'], predicted_dim=[1]) postprocessing_parameter=PostProcessingParameter(properties_to_process=['per_atom_energy'], per_atom_energy=PerAtomEnergy(normalize=False, from_atom_to_system_reduction=True, keep_per_atom_property=True), per_atom_charge=PerAtomCharge(conserve=True, conserve_strategy='default'), electrostatic_potential=ElectrostaticPotential(electrostatic_strategy='coulomb', maximum_interaction_radius=0.5), general_postprocessing_operation=GeneralPostProcessingOperation(calculate_molecular_self_energy=True, calculate_atomic_self_energy=False)) potential_seed=-1",
#  'nr_of_training_batches': 837}

# %%
extract_config(potential_parameter, "number_of_per_atom_features")
# Out:
# {'number_of_per_atom_features': 64}

# %%
extract_config(potential_parameter, "number_of_filters")
# Out:
# {'number_of_filters': 32}

# %%
extract_config(potential_parameter, "number_of_interaction_modules")
# Out:
# {'number_of_interaction_modules': 3}

# %%
runs[0].summary["test/per_system_energy/mae"]
# Out:
# 6.411189556121826

# %%
extract_config(extract_config(training_parameter, "splitting_strategy")["splitting_strategy"], "seed")
# Out:
# SplittingStrategy(name='random_record_splitting_strategy', data_split=[0.8, 0.1, 0.1], seed=42)
# {'seed': 42}

# %%
test_results = []

for run in runs:
    record = {}

    record.update({"name": run.name})

    potential_parameter = run.config["potential_parameter"]
    record.update(extract_config(potential_parameter, "number_of_per_atom_features"))
    record.update(extract_config(potential_parameter, "number_of_filters"))
    record.update(extract_config(potential_parameter, "number_of_interaction_modules"))

    record.update({
        "test/per_system_energy/mae": run.summary["test/per_system_energy/mae"],
        "test/per_system_energy/rmse": run.summary["test/per_system_energy/rmse"],
    })

    training_parameter = run.config["training_parameter"]
    record.update(
        extract_config(training_parameter, "seed")
    )

    record.update(
        {
            "atomic_number_embedding": True,
            "total_charge_embedding": False,
        }
    )

    test_results.append(record)

test_results_df = pd.DataFrame(test_results)

# %%
test_results_df.sort_values(by="test/per_system_energy/mae")
# Out:
#                 name  number_of_per_atom_features  number_of_filters  \
# 306    9_256_512(44)                          512                256
# 447  12_256_1024(45)                         1024                256
# 446   12_256_512(45)                          512                256
# 363   3_256_1024(45)                         1024                256
# 530    9_256_512(46)                          512                256
# ..               ...                          ...                ...
# 224      3_32_16(44)                           16                 32
# 323    12_128_32(44)                           32                128
# 328    12_256_16(44)                           16                256
# 232      3_64_32(44)                           32                 64
# 203     12_64_16(43)                           16                 64
#
#      number_of_interaction_modules  test/per_system_energy/mae  \
# 306                              9                    1.492873
# 447                             12                    1.509539
# 446                             12                    1.516618
# 363                              3                    1.527891
# 530                              9                    1.527987
# ..                             ...                         ...
# 224                              3                   10.917817
# 323                             12                   13.780708
# 328                             12                   24.392611
# 232                              3                   26.609879
# 203                             12                  151.139633
#
#      test/per_system_energy/rmse  seed  atomic_number_embedding  \
# 306                     3.512764    44                     True
# 447                     3.085273    45                     True
# 446                     3.000800    45                     True
# 363                     2.806468    45                     True
# 530                     3.974088    46                     True
# ..                           ...   ...                      ...
# 224                    15.203013    44                     True
# 323                    16.392054    44                     True
# 328                    30.475563    44                     True
# 232                    30.011641    44                     True
# 203                 16855.767578    43                     True
#
#      total_charge_embedding
# 306                   False
# 447                   False
# 446                   False
# 363                   False
# 530                   False
# ..                      ...
# 224                   False
# 323                   False
# 328                   False
# 232                   False
# 203                   False
#
# [560 rows x 9 columns]

# %% [markdown]
# ## Load trainings using atomic number and total charge embedding

# %% [raw]
# runs = api.runs(
#     "modelforge_nnps/schnet_qm9E_replica",
# )
# print(f"Found {len(runs)} runs")
# summary_list, config_list, name_list = [], [], []

# %% [raw]
# for run in runs:
#     record = {}
#
#     record.update({"name": run.name})
#
#     potential_parameter = run.config["potential_parameter"]
#     record.update(extract_config(potential_parameter, "number_of_per_atom_features"))
#     record.update(extract_config(potential_parameter, "number_of_filters"))
#     record.update(extract_config(potential_parameter, "number_of_interaction_modules"))
#
#     record.update({
#         "test/per_system_energy/mae": run.summary["test/per_system_energy/mae"],
#         "test/per_system_energy/rmse": run.summary["test/per_system_energy/rmse"],
#     })
#
#     training_parameter = run.config["training_parameter"]
#     record.update(
#         extract_config(extract_config(training_parameter, "splitting_strategy")["splitting_strategy"], "seed")
#     )
#
#     record.update(
#         {
#             "atomic_number_embedding": True,
#             "total_charge_embedding": True,
#         }
#     )
#
#     test_results.append(record)
#
# test_results_df = pd.DataFrame(test_results)

# %% [raw]
# test_results_df.sort_values(by="test/per_system_energy/rmse")

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
sns.set_context("notebook")
# %matplotlib inline

# %% [markdown]
# ### Dataset splitting consistency

# %%
ax = sns.boxplot(
    data=test_results_df,
    x="seed",
    y="test/per_system_energy/rmse",
    # hue="total_charge_embedding",
)
ax.set_title("Stability of dataset splitting")
# Out:
# Text(0.5, 1.0, 'Stability of dataset splitting')

# %%
ax = sns.boxplot(
    data=test_results_df,
    x="seed",
    y="test/per_system_energy/mae",
    # hue="total_charge_embedding",
)

ax.set_ylabel("test MAE (kJ/mol)")
ax.set_ylim(0, 175)
ax.set_title("Stability of dataset splitting")
# Out:
# Text(0.5, 1.0, 'Stability of dataset splitting')

# %% [raw]
# # seed 43 causing large error outliers, ignore for now
#
# test_results_df = test_results_df[test_results_df["seed"] != 43]

# %% [markdown]
# ### Impact of number_of_per_atom_features

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle("Impact of number_of_per_atom_features on test energy RMSE")

sns.boxplot(
    ax=axes[0],
    data=test_results_df,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue=None,
)
axes[0].set_ylim(0, 32)
axes[0].set_ylabel("test RMSE (kJ/mol)")

sns.boxplot(
    ax=axes[1],
    data=test_results_df,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[1].set_ylim(0, 32)
axes[1].set_ylabel("test RMSE (kJ/mol)")

sns.boxplot(
    ax=axes[2],
    data=test_results_df,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[2].set_ylim(0, 32)
axes[2].set_ylabel("test RMSE (kJ/mol)")

fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle("Impact of number_of_per_atom_features on test energy RMSE")

sns.boxplot(
    ax=axes[0],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 6],
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[0].set_ylim(0, 20)
axes[0].set_ylabel("test RMSE (kJ/mol)")
axes[0].set_title("(a) number_of_interaction_modules = 6")

sns.boxplot(
    ax=axes[1],
    data=test_results_df[test_results_df["number_of_filters"] == 128],
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[1].set_ylim(0, 20)
axes[1].set_ylabel("test RMSE (kJ/mol)")
axes[1].set_title("(b) number_of_filters = 128")

fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle("Impact of number_of_per_atom_features at each number_of_interaction_modules")

# RMSE
filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
sns.boxplot(
    ax=axes[0, 0],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[0, 0].set_ylim(0, 32)
axes[0, 0].set_ylabel("test RMSE (kJ/mol)")
axes[0, 0].set_title("number_of_interaction_modules = 3")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 6]
sns.boxplot(
    ax=axes[0, 1],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[0, 1].set_ylim(0, 32)
axes[0, 1].set_ylabel("test RMSE (kJ/mol)")
axes[0, 1].set_title("number_of_interaction_modules = 6")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 9]
sns.boxplot(
    ax=axes[0, 2],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[0, 2].set_ylim(0, 32)
axes[0, 2].set_ylabel("test RMSE (kJ/mol)")
axes[0, 2].set_title("number_of_interaction_modules = 9")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 12]
sns.boxplot(
    ax=axes[0, 3],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_filters",
)
axes[0, 3].set_ylim(0, 32)
axes[0, 3].set_ylabel("test RMSE (kJ/mol)")
axes[0, 3].set_title("number_of_interaction_modules = 12")

# MAE
filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
sns.boxplot(
    ax=axes[1, 0],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_filters",
)
axes[1, 0].set_ylim(0, 32)
axes[1, 0].set_ylabel("test MAE (kJ/mol)")
axes[1, 0].set_title("number_of_interaction_modules = 3")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 6]
sns.boxplot(
    ax=axes[1, 1],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_filters",
)
axes[1, 1].set_ylim(0, 32)
axes[1, 1].set_ylabel("test MAE (kJ/mol)")
axes[1, 1].set_title("number_of_interaction_modules = 6")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 9]
sns.boxplot(
    ax=axes[1, 2],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_filters",
)
axes[1, 2].set_ylim(0, 32)
axes[1, 2].set_ylabel("test MAE (kJ/mol)")
axes[1, 2].set_title("number_of_interaction_modules = 9")

filtered_results = test_results_df[test_results_df["number_of_interaction_modules"] == 12]
sns.boxplot(
    ax=axes[1, 3],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_filters",
)
axes[1, 3].set_ylim(0, 32)
axes[1, 3].set_ylabel("test MAE (kJ/mol)")
axes[1, 3].set_title("number_of_interaction_modules = 12")

fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle("Impact of number_of_per_atom_features at each number_of_filters")

# RMSE
filtered_results = test_results_df[test_results_df["number_of_filters"] == 32]
sns.boxplot(
    ax=axes[0, 0],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[0, 0].set_ylim(0, 32)
axes[0, 0].set_ylabel("test RMSE (kJ/mol)")
axes[0, 0].set_title("number_of_filters = 32")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 64]
sns.boxplot(
    ax=axes[0, 1],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[0, 1].set_ylim(0, 32)
axes[0, 1].set_ylabel("test RMSE (kJ/mol)")
axes[0, 1].set_title("number_of_filters = 64")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 128]
sns.boxplot(
    ax=axes[0, 2],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[0, 2].set_ylim(0, 32)
axes[0, 2].set_ylabel("test RMSE (kJ/mol)")
axes[0, 2].set_title("number_of_filters = 128")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 256]
sns.boxplot(
    ax=axes[0, 3],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/rmse",
    hue="number_of_interaction_modules",
)
axes[0, 3].set_ylim(0, 32)
axes[0, 3].set_ylabel("test RMSE (kJ/mol)")
axes[0, 3].set_title("number_of_filters = 256")

# MAE
filtered_results = test_results_df[test_results_df["number_of_filters"] == 32]
sns.boxplot(
    ax=axes[1, 0],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_interaction_modules",
)
axes[1, 0].set_ylim(0, 32)
axes[1, 0].set_ylabel("test MAE (kJ/mol)")
axes[1, 0].set_title("number_of_filters = 32")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 64]
sns.boxplot(
    ax=axes[1, 1],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_interaction_modules",
)
axes[1, 1].set_ylim(0, 32)
axes[1, 1].set_ylabel("test MAE (kJ/mol)")
axes[1, 1].set_title("number_of_filters = 64")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 128]
sns.boxplot(
    ax=axes[1, 2],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_interaction_modules",
)
axes[1, 2].set_ylim(0, 32)
axes[1, 2].set_ylabel("test MAE (kJ/mol)")
axes[1, 2].set_title("number_of_filters = 128")

filtered_results = test_results_df[test_results_df["number_of_filters"] == 256]
sns.boxplot(
    ax=axes[1, 3],
    data=filtered_results,
    x="number_of_per_atom_features",
    y="test/per_system_energy/mae",
    hue="number_of_interaction_modules",
)
axes[1, 3].set_ylim(0, 32)
axes[1, 3].set_ylabel("test MAE (kJ/mol)")
axes[1, 3].set_title("number_of_filters = 256")

fig.tight_layout()

# %%
exp_results_df = test_results_df#[(test_results_df["number_of_per_atom_features"] == 256)]

# %%
exp_results_df
# Out:
#                 name  number_of_per_atom_features  number_of_filters  \
# 0        3_32_64(42)                           64                 32
# 1       3_32_128(42)                          128                 32
# 2        3_32_32(42)                           32                 32
# 3        3_32_16(42)                           16                 32
# 4       3_32_256(42)                          256                 32
# ..               ...                          ...                ...
# 555    12_256_32(46)                           32                256
# 556   12_256_128(46)                          128                256
# 557   12_256_256(46)                          256                256
# 558   12_256_512(46)                          512                256
# 559  12_256_1024(46)                         1024                256
#
#      number_of_interaction_modules  test/per_system_energy/mae  \
# 0                                3                    6.411190
# 1                                3                    3.829239
# 2                                3                    6.810791
# 3                                3                   10.446414
# 4                                3                    3.791241
# ..                             ...                         ...
# 555                             12                    3.322468
# 556                             12                    2.275876
# 557                             12                    1.879934
# 558                             12                    1.587741
# 559                             12                    1.619853
#
#      test/per_system_energy/rmse  seed  atomic_number_embedding  \
# 0                       9.486845    42                     True
# 1                       6.024316    42                     True
# 2                      10.236305    42                     True
# 3                      15.117289    42                     True
# 4                       6.255589    42                     True
# ..                           ...   ...                      ...
# 555                     5.981883    46                     True
# 556                     5.372967    46                     True
# 557                     4.648311    46                     True
# 558                     4.043679    46                     True
# 559                     4.439447    46                     True
#
#      total_charge_embedding
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 555                   False
# 556                   False
# 557                   False
# 558                   False
# 559                   False
#
# [560 rows x 9 columns]

# %%
fig, axes = plt.subplots(4, 4, figsize=(20, 16))
fig.suptitle("Impact of number_of_per_atom_features on test energy MAE")

for i, number_of_filters in enumerate([32, 64, 128, 256]):
    for j, number_of_interaction_modules in enumerate([3, 6, 9, 12]):
        plot_results = exp_results_df[
            (exp_results_df["number_of_filters"] == number_of_filters) & \
            (exp_results_df["number_of_interaction_modules"] == number_of_interaction_modules)
        ]
        sns.boxplot(
            ax=axes[i, j],
            data=plot_results,
            x="number_of_per_atom_features",
            y="test/per_system_energy/mae",
            # hue="maximum_interaction_radius",
        )
        sns.stripplot(
            ax=axes[i, j],
            data=plot_results, 
            x="number_of_per_atom_features",
            y="test/per_system_energy/mae",
            # hue="maximum_interaction_radius",
            # legend=False,
        )
        axes[i, j].set_ylim(1, 12)
        axes[i, j].set_ylabel("test MAE (kJ/mol)")
        axes[i, j].set_title(f"number_of_filters {number_of_filters}; number_of_interaction_modules {number_of_interaction_modules}")

fig.tight_layout()

# %% [markdown]
# At number_of_per_atom_features >= 128, test RMSE is close to minimum.

# %%
test_results_df = test_results_df[test_results_df["number_of_per_atom_features"] == 512]

# %% [markdown]
# ### Impact of number_of_filters v.s. number_of_interaction_modules

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle("Impact of number_of_filters v.s. number_of_interaction_modules on test energy MAE")

sns.boxplot(
    ax=axes[0],
    data=test_results_df[test_results_df["number_of_filters"] == 256],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_filters",
)
sns.stripplot(
    ax=axes[0],
    data=test_results_df[test_results_df["number_of_filters"] == 256],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
)
axes[0].set_ylim(1.25, 3.25)
axes[0].set_ylabel("test MAE (kJ/mol)")
axes[0].set_title("number_of_filters = 256")

sns.boxplot(
    ax=axes[1],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 9],
    x="number_of_filters",
    y="test/per_system_energy/mae",
    # hue="number_of_interaction_modules",
)
sns.stripplot(
    ax=axes[1],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 9],
    x="number_of_filters",
    y="test/per_system_energy/mae",
)
axes[1].set_ylim(1.25, 3.25)
axes[1].set_ylabel("test MAE (kJ/mol)")
axes[1].set_title("number_of_interaction_modules = 9")

fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle("Impact of number_of_filters v.s. number_of_interaction_modules on test energy MAE")

# fixed number_of_interaction_modules
sns.boxplot(
    ax=axes[0, 0],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 3],
    x="number_of_filters",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[0, 0].set_ylim(1, 4)
axes[0, 0].set_ylabel("test MAE (kJ/mol)")
axes[0, 0].set_title("number_of_interaction_modules = 3")

sns.boxplot(
    ax=axes[0, 1],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 6],
    x="number_of_filters",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[0, 1].set_ylim(1, 4)
axes[0, 1].set_ylabel("test MAE (kJ/mol)")
axes[0, 1].set_title("number_of_interaction_modules = 6")

sns.boxplot(
    ax=axes[0, 2],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 9],
    x="number_of_filters",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[0, 2].set_ylim(1, 4)
axes[0, 2].set_ylabel("test mae (kJ/mol)")
axes[0, 2].set_title("number_of_interaction_modules = 9")

sns.boxplot(
    ax=axes[0, 3],
    data=test_results_df[test_results_df["number_of_interaction_modules"] == 12],
    x="number_of_filters",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[0, 3].set_ylim(1, 4)
axes[0, 3].set_ylabel("test MAE (kJ/mol)")
axes[0, 3].set_title("number_of_interaction_modules = 12")

# fixed number_of_filters
sns.boxplot(
    ax=axes[1, 0],
    data=test_results_df[test_results_df["number_of_filters"] == 32],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
sns.stripplot(
    ax=axes[1, 0],
    data=test_results_df[test_results_df["number_of_filters"] == 32],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[1, 0].set_ylim(1, 4)
axes[1, 0].set_ylabel("test MAE (kJ/mol)")
axes[1, 0].set_title("number_of_filters = 32")

sns.boxplot(
    ax=axes[1, 1],
    data=test_results_df[test_results_df["number_of_filters"] == 64],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[1, 1].set_ylim(1, 4)
axes[1, 1].set_ylabel("test MAE (kJ/mol)")
axes[1, 1].set_title("number_of_filters = 64")

sns.boxplot(
    ax=axes[1, 2],
    data=test_results_df[test_results_df["number_of_filters"] == 128],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[1, 2].set_ylim(1, 4)
axes[1, 2].set_ylabel("test MAE (kJ/mol)")
axes[1, 2].set_title("number_of_filters = 128")

sns.boxplot(
    ax=axes[1, 3],
    data=test_results_df[test_results_df["number_of_filters"] == 256],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
sns.stripplot(
    ax=axes[1, 3],
    data=test_results_df[test_results_df["number_of_filters"] == 256],
    x="number_of_interaction_modules",
    y="test/per_system_energy/mae",
    # hue="number_of_per_atom_features",
)
axes[1, 3].set_ylim(1, 4)
axes[1, 3].set_ylabel("test MAE (kJ/mol)")
axes[1, 3].set_title("number_of_filters = 256")

fig.tight_layout()
plt.show()

# %% [raw]
# ### Impact of the total charge embedding

# %% [raw]
# fig, axes = plt.subplots(1, 4, figsize=(20, 5))
# fig.suptitle("Impact of the total_charge_embedding")
#
# sns.boxplot(
#     ax=axes[0],
#     data=test_results_df,
#     x="total_charge_embedding",
#     y="test/per_system_energy/rmse",
# )
# axes[0].set_ylim(2.5, 8.2)
# axes[0].set_ylabel("test RMSE (kJ/mol)")
#
# sns.boxplot(
#     ax=axes[1],
#     data=test_results_df,
#     x="number_of_per_atom_features",
#     y="test/per_system_energy/rmse",
#     hue="total_charge_embedding",
# )
# axes[1].set_ylim(2.5, 8.2)
# axes[1].set_ylabel("test RMSE (kJ/mol)")
#
# sns.boxplot(
#     ax=axes[2],
#     data=test_results_df,
#     x="number_of_filters",
#     y="test/per_system_energy/rmse",
#     hue="total_charge_embedding",
# )
# axes[2].set_ylim(2.5, 8.2)
# axes[2].set_ylabel("test RMSE (kJ/mol)")
#
# sns.boxplot(
#     ax=axes[3],
#     data=test_results_df,
#     x="number_of_interaction_modules",
#     y="test/per_system_energy/rmse",
#     hue="total_charge_embedding",
# )
# axes[3].set_ylim(2.5, 8.2)
# axes[3].set_ylabel("test RMSE (kJ/mol)")
#
# fig.tight_layout()

# %% [markdown]
# ### Compuation resource consumption

# %%
runs[0].history(stream="events")
# Out:
#      system.disk./.usageGB  _wandb  system.disk.out     _runtime  \
# 0                31.143703    True              0.0    10.552891
# 1                      NaN    True              NaN    10.553593
# 2                31.143719    True              0.0    40.555583
# 3                      NaN    True              NaN    40.573134
# 4                      NaN    True              NaN    50.543494
# ..                     ...     ...              ...          ...
# 517                    NaN    True              NaN  6070.553566
# 518                    NaN    True              NaN  6080.561113
# 519                    NaN    True              NaN  6110.551040
# 520                    NaN    True              NaN  6110.562729
# 521                    NaN    True              NaN  6120.553461
#
#      system.disk./.usagePercent  system.disk.in    _timestamp  \
# 0                     36.031450             0.0  1.742957e+09
# 1                           NaN             NaN  1.742957e+09
# 2                     36.031468             0.0  1.742957e+09
# 3                           NaN             NaN  1.742957e+09
# 4                           NaN             NaN  1.742957e+09
# ..                          ...             ...           ...
# 517                         NaN             NaN  1.742963e+09
# 518                         NaN             NaN  1.742963e+09
# 519                         NaN             NaN  1.742963e+09
# 520                         NaN             NaN  1.742963e+09
# 521                         NaN             NaN  1.742963e+09
#
#      system.network.sent  system.network.recv  system.gpu.0.powerPercent  ...  \
# 0                    NaN                  NaN                        NaN  ...
# 1           3.808432e+06             504043.0                        NaN  ...
# 2                    NaN                  NaN                        NaN  ...
# 3                    NaN                  NaN                  25.889667  ...
# 4                    NaN                  NaN                        NaN  ...
# ..                   ...                  ...                        ...  ...
# 517                  NaN                  NaN                  22.231000  ...
# 518                  NaN                  NaN                  23.767667  ...
# 519         2.456927e+09          288247076.0                        NaN  ...
# 520                  NaN                  NaN                        NaN  ...
# 521         2.461335e+09          288883106.0                        NaN  ...
#
#      system.cpu.58.cpu_percent  system.cpu.57.cpu_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 517                        NaN                        NaN
# 518                        NaN                        NaN
# 519                        NaN                        NaN
# 520                   0.100402                        0.1
# 521                        NaN                        NaN
#
#      system.cpu.55.cpu_percent  system.cpu.8.cpu_percent  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 517                        NaN                       NaN
# 518                        NaN                       NaN
# 519                        NaN                       NaN
# 520                   1.203611                       0.0
# 521                        NaN                       NaN
#
#      system.cpu.59.cpu_percent  system.cpu.38.cpu_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 517                        NaN                        NaN
# 518                        NaN                        NaN
# 519                        NaN                        NaN
# 520                        0.1                        0.0
# 521                        NaN                        NaN
#
#      system.cpu.18.cpu_percent  system.cpu.17.cpu_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 517                        NaN                        NaN
# 518                        NaN                        NaN
# 519                        NaN                        NaN
# 520                        0.0                        0.0
# 521                        NaN                        NaN
#
#      system.cpu.14.cpu_percent  system.cpu.30.cpu_percent
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 517                        NaN                        NaN
# 518                        NaN                        NaN
# 519                        NaN                        NaN
# 520                   0.199601                      100.0
# 521                        NaN                        NaN
#
# [522 rows x 92 columns]

# %% [markdown]
# ### Heat map

# %%
test_results_df
# Out:
#                 name  number_of_per_atom_features  number_of_filters  \
# 0        3_32_64(42)                           64                 32
# 1       3_32_128(42)                          128                 32
# 2        3_32_32(42)                           32                 32
# 3        3_32_16(42)                           16                 32
# 4       3_32_256(42)                          256                 32
# ..               ...                          ...                ...
# 555    12_256_32(46)                           32                256
# 556   12_256_128(46)                          128                256
# 557   12_256_256(46)                          256                256
# 558   12_256_512(46)                          512                256
# 559  12_256_1024(46)                         1024                256
#
#      number_of_interaction_modules  test/per_system_energy/mae  \
# 0                                3                    6.411190
# 1                                3                    3.829239
# 2                                3                    6.810791
# 3                                3                   10.446414
# 4                                3                    3.791241
# ..                             ...                         ...
# 555                             12                    3.322468
# 556                             12                    2.275876
# 557                             12                    1.879934
# 558                             12                    1.587741
# 559                             12                    1.619853
#
#      test/per_system_energy/rmse  seed  atomic_number_embedding  \
# 0                       9.486845    42                     True
# 1                       6.024316    42                     True
# 2                      10.236305    42                     True
# 3                      15.117289    42                     True
# 4                       6.255589    42                     True
# ..                           ...   ...                      ...
# 555                     5.981883    46                     True
# 556                     5.372967    46                     True
# 557                     4.648311    46                     True
# 558                     4.043679    46                     True
# 559                     4.439447    46                     True
#
#      total_charge_embedding
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 555                   False
# 556                   False
# 557                   False
# 558                   False
# 559                   False
#
# [448 rows x 9 columns]

# %%
for i in [3, 6, 9, 12]:
    mean_heatmap_df = test_results_df[test_results_df["number_of_interaction_modules"] == i][["number_of_per_atom_features", "number_of_filters", "test/per_system_energy/mae"]].groupby(["number_of_filters", "number_of_per_atom_features"]).agg("mean").reset_index()
    std_heatmap_df = test_results_df[test_results_df["number_of_interaction_modules"] == i][["number_of_per_atom_features", "number_of_filters", "test/per_system_energy/mae"]].groupby(["number_of_filters", "number_of_per_atom_features"]).agg("std").reset_index()
    mean_heatmap_df = mean_heatmap_df.pivot(
        index="number_of_filters",
        columns="number_of_per_atom_features",
        values="test/per_system_energy/mae",
    )
    std_heatmap_df = std_heatmap_df.pivot(
        index="number_of_filters",
        columns="number_of_per_atom_features",
        values="test/per_system_energy/mae",
    )
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f"Number of interaction modules: {i}")
    sns.heatmap(
        ax=axes[0],
        data=mean_heatmap_df,
        annot=True, 
        fmt=".3f",
        cmap='OrRd',
        vmin=1,
        vmax=8,
    )
    axes[0].set_title("Test energy MAE mean (kJ/mol)")
    sns.heatmap(
        ax=axes[1],
        data=std_heatmap_df,
        annot=True, 
        fmt=".2f",
        cmap='GnBu',
        vmin=0,
        vmax=3,
    )
    axes[1].set_title("Test energy MAE standard deviation (kJ/mol)")

# %% [markdown]
# ## exp02_4

# %%
import numpy as np
import pandas as pd
import wandb

from analysis.helper import extract_config

api = wandb.Api()
runs = api.runs(
    "modelforge_nnps/schnet_qm9",
    filters={"state": "finished", "group": "exp02_4"},
)
print(f"Found {len(runs)} runs")
summary_list, config_list, name_list = [], [], []
# Out:
# Found 38 runs

# %%
exp_results = []

for run in runs:
    record = {}

    record.update({"name": run.name})

    potential_parameter = run.config["potential_parameter"]
    record.update(extract_config(potential_parameter, "number_of_radial_basis_functions"))

    try:
        record.update({
            "test/per_system_energy/mae": run.summary["test/per_system_energy/mae"],
            "test/per_system_energy/rmse": run.summary["test/per_system_energy/rmse"],
        })
    except:
        record.update({
                "test/per_system_energy/mae": np.nan,
                "test/per_system_energy/rmse": np.nan,
            })

    training_parameter = run.config["training_parameter"]
    record.update(
        extract_config(training_parameter, "seed")
    )

    exp_results.append(record)

exp_results_df = pd.DataFrame(exp_results)

# %%
ax = sns.boxplot(
    data=exp_results_df,
    x="number_of_radial_basis_functions",
    y="test/per_system_energy/mae",
)
sns.stripplot(
    ax=ax,
    data=exp_results_df,
    x="number_of_radial_basis_functions",
    y="test/per_system_energy/mae",
    legend=False,
)
ax.set_ylabel("test energy MAE (kJ/mol)")
# Out:
# Text(0, 0.5, 'test energy MAE (kJ/mol)')

# %% [markdown]
# ### exp02_5

# %%
import numpy as np
import pandas as pd
import wandb

from analysis.helper import extract_config

api = wandb.Api()
runs = api.runs(
    "modelforge_nnps/schnet_qm9",
    filters={"state": "finished", "group": "exp02_5"},
)
print(f"Found {len(runs)} runs")
summary_list, config_list, name_list = [], [], []
# Out:
# Found 15 runs

# %%
exp_results = []

for run in runs:
    record = {}

    record.update({"name": run.name})

    potential_parameter = run.config["potential_parameter"]
    record.update(extract_config(potential_parameter, "number_of_radial_basis_functions"))

    try:
        record.update({
            "test/per_system_energy/mae": run.summary["test/per_system_energy/mae"],
            "test/per_system_energy/rmse": run.summary["test/per_system_energy/rmse"],
            "test/per_atom_force/mae": run.summary["test/per_atom_force/mae"],
            "test/per_atom_force/rmse": run.summary["test/per_atom_force/rmse"],
        })
    except:
        record.update({
                "test/per_system_energy/mae": np.nan,
                "test/per_system_energy/rmse": np.nan,
                "test/per_atom_force/mae": np.nan,
                "test/per_atom_force/rmse": np.nan,
            })

    training_parameter = run.config["training_parameter"]
    record.update(
        extract_config(training_parameter, "seed")
    )

    record["F"] = float(record["name"][7:-5])

    exp_results.append(record)

exp_results_df = pd.DataFrame(exp_results)

# %%
exp_results_df
# Out:
#                  name  number_of_radial_basis_functions  \
# 0   02(5)_F0.001_(44)                               128
# 1   02(5)_F0.001_(45)                               128
# 2     02(5)_F0.1_(44)                               128
# 3     02(5)_F0.1_(45)                               128
# 4   02(5)_F0.001_(46)                               128
# 5     02(5)_F0.1_(46)                               128
# 6       02(5)_F0_(42)                               128
# 7   02(5)_F0.001_(42)                               128
# 8   02(5)_F0.001_(43)                               128
# 9     02(5)_F0.1_(42)                               128
# 10      02(5)_F0_(43)                               128
# 11    02(5)_F0.1_(43)                               128
# 12      02(5)_F0_(44)                               128
# 13      02(5)_F0_(45)                               128
# 14      02(5)_F0_(46)                               128
#
#     test/per_system_energy/mae  test/per_system_energy/rmse  \
# 0                     2.124718                     3.587194
# 1                     2.244088                     3.817067
# 2                     4.433734                     6.999398
# 3                     4.600693                     7.185257
# 4                     2.731268                     4.826219
# 5                     4.322163                     7.100802
# 6                          NaN                          NaN
# 7                     2.309204                     4.130820
# 8                     2.656205                     4.641889
# 9                     3.688539                     5.751830
# 10                    2.408362                     4.669912
# 11                    4.040376                     6.942374
# 12                    1.813192                     3.326661
# 13                    2.188337                     3.785207
# 14                    2.427250                     5.083084
#
#     test/per_atom_force/mae  test/per_atom_force/rmse  seed      F
# 0                 57.285038                 92.033524    44  0.001
# 1                 61.789139                103.093193    45  0.001
# 2                 13.156528                 23.317530    44  0.100
# 3                 14.126784                 24.481901    45  0.100
# 4                 74.343262                119.463165    46  0.001
# 5                 12.945390                 22.201788    46  0.100
# 6                       NaN                       NaN    42  0.000
# 7                 63.218292                102.872208    42  0.001
# 8                 72.409790                119.175209    43  0.001
# 9                 11.215037                 20.266323    42  0.100
# 10               995.119751               1408.974854    43  0.000
# 11                12.237335                 21.660608    43  0.100
# 12               877.418762               1294.491455    44  0.000
# 13              1114.502563               1575.279541    45  0.000
# 14              1136.842407               1549.067749    46  0.000

# %%
ax = sns.boxplot(
    data=exp_results_df,
    x="F",
    y="test/per_system_energy/mae",
)
sns.stripplot(
    ax=ax,
    data=exp_results_df,
    x="F",
    y="test/per_system_energy/mae",
    legend=False,
)
ax.set_xlabel("Force loss weight")
ax.set_ylabel("test energy MAE (kJ/mol)")
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.show()

# %%
ax = sns.boxplot(
    data=exp_results_df,
    x="F",
    y="test/per_atom_force/mae",
)
sns.stripplot(
    ax=ax,
    data=exp_results_df,
    x="F",
    y="test/per_atom_force/mae",
    legend=False,
)
ax.set_xlabel("Force loss weight")
ax.set_ylabel("test energy MAE (kJ/mol)")
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# ax.set_ylim(0, 100)

plt.show()

# %% [markdown]
# # SchNet QM9 landscape

# %%
import wandb
import numpy as np
import pandas as pd

from analysis.helper import extract_config

api = wandb.Api()
runs = api.runs(
    "modelforge_nnps/NNP_hyperparameter_landscape",
    filters={"group": "SchNet-QM9", "state": "finished"},
)
print(f"Found {len(runs)} runs")
summary_list, config_list, name_list = [], [], []
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/syan/.netrc.
# Found 2500 runs

# %%
test_results = []

for run in runs:
    record = {}

    record.update({"id": run.id})
    record.update({"name": run.name})

    try:
        record.update({
            "test/per_system_energy/mae": run.summary["test/per_system_energy/mae"],
            "test/per_system_energy/rmse": run.summary["test/per_system_energy/rmse"],
        })
    except KeyError:
        record.update({
            "test/per_system_energy/mae": np.nan,
            "test/per_system_energy/rmse": np.nan,
        })

    potential_parameter = run.config["potential_parameter"]
    record.update(extract_config(potential_parameter, "number_of_radial_basis_functions"))
    record.update(extract_config(potential_parameter, "number_of_interaction_modules"))
    record.update(extract_config(potential_parameter, "number_of_filters"))
    record.update(extract_config(potential_parameter, "number_of_per_atom_features"))

    # system usage
    record.update(
        {
            "GPU_usage": run.history(stream='events')["system.gpu.0.memoryAllocatedBytes"].max() / 1024 / 1024 / 1024,  # maximum GPU memory used in GB
            "runtime": run.history(stream='events')["_runtime"].max() / 60,  # last value in the array -- last epoch in min
        }
    )

    training_parameter = run.config["training_parameter"]
    record.update(
        extract_config(training_parameter, "seed")
    )

    test_results.append(record)

test_results_df = pd.DataFrame(test_results)

# %%
test_results_df.sort_values(by="test/per_system_energy/mae").head(20)
# Out:
#             id            name  test/per_system_energy/mae  \
# 2074  rhciz4mx  SchNet_QM92074                    1.449455
# 1797  bigyfll9  SchNet_QM91797                    1.519094
# 1874  i6xkedxp  SchNet_QM91874                    1.523335
# 75    ue662n92  SchNet_QM90074                    1.538604
# 799   lokrund9  SchNet_QM90798                    1.542607
# 898   whda246x  SchNet_QM90897                    1.544988
# 2299  a6uw37kd  SchNet_QM92299                    1.551206
# 1697  n87winel  SchNet_QM91698                    1.554772
# 299   bz37p6ax  SchNet_QM90298                    1.566668
# 1899  57y0yo7b  SchNet_QM91899                    1.569504
# 174   u9730o0h  SchNet_QM90173                    1.571833
# 675   z64qf57l  SchNet_QM90674                    1.572471
# 199   dasng9rj  SchNet_QM90198                    1.574178
# 1573  r1npc8lz  SchNet_QM91573                    1.585830
# 300   dvmk6s50  SchNet_QM90299                    1.599997
# 700   lwnhhoje  SchNet_QM90699                    1.600167
# 400   fyhzepxa  SchNet_QM90399                    1.602231
# 198   h1pykgwc  SchNet_QM90197                    1.602279
# 798   m85zju24  SchNet_QM90797                    1.603159
# 1799  74wd7mpu  SchNet_QM91799                    1.612621
#
#       test/per_system_energy/rmse  number_of_radial_basis_functions  \
# 2074                     4.213008                                16
# 1797                     3.095916                                64
# 1874                     3.713080                               128
# 75                       4.242535                                16
# 799                      7.376099                                64
# 898                      3.989720                               128
# 2299                     4.760719                                64
# 1697                     2.783655                                32
# 299                      4.010064                                64
# 1899                     3.414593                               128
# 174                      4.175549                                32
# 675                      4.453844                                32
# 199                      4.196766                                32
# 1573                     2.773346                                16
# 300                      4.123442                                64
# 700                      4.417526                                32
# 400                      4.694376                               128
# 198                      3.865434                                32
# 798                      5.378717                                64
# 1799                     3.279442                                64
#
#       number_of_interaction_modules  number_of_filters  \
# 2074                              6                512
# 1797                              9                512
# 1874                              6                512
# 75                                6                512
# 799                               9                512
# 898                               9                512
# 2299                              9                512
# 1697                              9                512
# 299                               9                512
# 1899                              9                512
# 174                               6                512
# 675                               6                512
# 199                               9                512
# 1573                              6                512
# 300                               9                512
# 700                               9                512
# 400                               9                512
# 198                               9                512
# 798                               9                512
# 1799                              9                512
#
#       number_of_per_atom_features  GPU_usage     runtime  seed
# 2074                          512   4.776245  214.763354    46
# 1797                          128   8.073120  216.761966    45
# 1874                          512   5.940308  202.010389    45
# 75                            512   8.159058  233.012409    42
# 799                           256   8.123901  209.510546    43
# 898                           128   8.168823  271.764777    43
# 2299                          512   6.602417  200.510833    46
# 1697                          256   8.157104  242.013770    45
# 299                           256   8.055542  209.510146    42
# 1899                          512   6.633667  203.509537    45
# 174                           256   5.752808  195.510501    42
# 675                           512   5.887573  169.261782    43
# 199                           256   9.586792  206.761612    42
# 1573                          256   7.002808  175.760674    45
# 300                           512   9.830933  194.511377    42
# 700                           512   8.307495  236.011341    43
# 400                           512   9.752808  207.260809    42
# 198                           128   9.623901  263.510213    42
# 798                           128   8.121948  212.015845    43
# 1799                          512   8.295776  254.509660    45

# %%
test_results_df.to_csv("schnet_qm9.csv")

# %%
fig, axes = plt.subplots(5, 5, figsize=(30, 30))
# fig.suptitle("Impact of number_of_per_atom_features on test energy MAE")

for i, number_of_filters in enumerate([32, 64, 128, 256, 512]):
    for j, number_of_per_atom_features in enumerate([32, 64, 128, 256, 512]):
        plot_results = test_results_df
        # plot_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
        plot_results = plot_results[
            (plot_results["number_of_filters"] == number_of_filters) & \
            (plot_results["number_of_per_atom_features"] == number_of_per_atom_features)
        ]
        sns.boxplot(
            ax=axes[i, j],
            data=plot_results,
            x="number_of_radial_basis_functions",
            y="test/per_system_energy/mae",
            hue="number_of_interaction_modules",
        )
        sns.stripplot(
            ax=axes[i, j],
            data=plot_results, 
            x="number_of_radial_basis_functions",
            y="test/per_system_energy/mae",
            hue="number_of_interaction_modules",
            legend=False,
        )
        # axes[i, j].set_ylim(1, 20)
        axes[i, j].set_ylabel("test MAE (kJ/mol)")
        axes[i, j].set_title(f"number_of_filters {number_of_filters}; number_of_per_atom_features {number_of_per_atom_features}")

fig.tight_layout()
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-145' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-146' coro=<Kernel.shell_main() running at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# /Users/syan/miniforge3/envs/modelforge/lib/python3.12/collections/__init__.py:449: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   result = tuple_new(cls, iterable)
# Task was destroyed but it is pending!
# task: <Task pending name='Task-146' coro=<Kernel.shell_main() running at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-163' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-164' coro=<Kernel.shell_main() running at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-164' coro=<Kernel.shell_main() running at /Users/syan/miniforge3/envs/modelforge/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]>

# %%
fig, axes = plt.subplots(5, 5, figsize=(30, 30))
# fig.suptitle("Impact of number_of_per_atom_features on test energy MAE")

for i, number_of_filters in enumerate([32, 64, 128, 256, 512]):
    for j, number_of_per_atom_features in enumerate([32, 64, 128, 256, 512]):
        # plot_results = test_results_df
        plot_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
        plot_results = plot_results[
            (plot_results["number_of_filters"] == number_of_filters) & \
            (plot_results["number_of_per_atom_features"] == number_of_per_atom_features)
        ]
        sns.boxplot(
            ax=axes[i, j],
            data=plot_results,
            x="number_of_radial_basis_functions",
            y="test/per_system_energy/mae",
            # hue="number_of_interaction_modules",
        )
        sns.stripplot(
            ax=axes[i, j],
            data=plot_results, 
            x="number_of_radial_basis_functions",
            y="test/per_system_energy/mae",
            # hue="number_of_interaction_modules",
            # legend=False,
        )
        axes[i, j].set_ylim(1.4, 4)
        axes[i, j].set_ylabel("test MAE (kJ/mol)")
        axes[i, j].set_title(f"number_of_filters {number_of_filters}; number_of_per_atom_features {number_of_per_atom_features}")

fig.tight_layout()

# %%
fig, axes = plt.subplots(5, 5, figsize=(30, 30))
# fig.suptitle("Impact of number_of_per_atom_features on test energy MAE")

for i, number_of_filters in enumerate([32, 64, 128, 256, 512]):
    for j, number_of_per_atom_features in enumerate([32, 64, 128, 256, 512]):
        plot_results = test_results_df
        # plot_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
        plot_results = plot_results[
            (plot_results["number_of_filters"] == number_of_filters) & \
            (plot_results["number_of_per_atom_features"] == number_of_per_atom_features)
        ]
        sns.boxplot(
            ax=axes[i, j],
            data=plot_results,
            x="number_of_radial_basis_functions",
            y="runtime",
            hue="number_of_interaction_modules",
        )
        sns.stripplot(
            ax=axes[i, j],
            data=plot_results, 
            x="number_of_radial_basis_functions",
            y="runtime",
            hue="number_of_interaction_modules",
            legend=False,
        )
        axes[i, j].set_ylim(50, 200)
        axes[i, j].set_ylabel("test MAE (kJ/mol)")
        axes[i, j].set_title(f"number_of_filters {number_of_filters}; number_of_per_atom_features {number_of_per_atom_features}")

fig.tight_layout()

# %%
fig, axes = plt.subplots(5, 5, figsize=(30, 30))
# fig.suptitle("Impact of number_of_per_atom_features on test energy MAE")

for i, number_of_filters in enumerate([32, 64, 128, 256, 512]):
    for j, number_of_per_atom_features in enumerate([32, 64, 128, 256, 512]):
        plot_results = test_results_df
        # plot_results = test_results_df[test_results_df["number_of_interaction_modules"] == 3]
        plot_results = plot_results[
            (plot_results["number_of_filters"] == number_of_filters) & \
            (plot_results["number_of_per_atom_features"] == number_of_per_atom_features)
        ]
        sns.boxplot(
            ax=axes[i, j],
            data=plot_results,
            x="number_of_radial_basis_functions",
            y="GPU_usage",
            hue="number_of_interaction_modules",
        )
        sns.stripplot(
            ax=axes[i, j],
            data=plot_results, 
            x="number_of_radial_basis_functions",
            y="GPU_usage",
            hue="number_of_interaction_modules",
            legend=False,
        )
        axes[i, j].set_ylim(0.5, 15)
        axes[i, j].set_ylabel("test MAE (kJ/mol)")
        axes[i, j].set_title(f"number_of_filters {number_of_filters}; number_of_per_atom_features {number_of_per_atom_features}")

fig.tight_layout()

# %% [markdown]
# ### Heatmaps

# %%
for number_of_interaction_modules in [1, 3, 6, 9]:
    for number_of_radial_basis_functions in [16, 32, 64, 128, 256]:
        mean_heatmap_df = test_results_df[(test_results_df["number_of_interaction_modules"] == number_of_interaction_modules) & (test_results_df["number_of_radial_basis_functions"] == number_of_radial_basis_functions)][["number_of_per_atom_features", "number_of_filters", "test/per_system_energy/mae"]].groupby(["number_of_filters", "number_of_per_atom_features"]).agg("mean").reset_index()
        std_heatmap_df = test_results_df[(test_results_df["number_of_interaction_modules"] == number_of_interaction_modules) & (test_results_df["number_of_radial_basis_functions"] == number_of_radial_basis_functions)][["number_of_per_atom_features", "number_of_filters", "test/per_system_energy/mae"]].groupby(["number_of_filters", "number_of_per_atom_features"]).agg("std").reset_index()
        mean_heatmap_df = mean_heatmap_df.pivot(
            index="number_of_filters",
            columns="number_of_per_atom_features",
            values="test/per_system_energy/mae",
        )
        std_heatmap_df = std_heatmap_df.pivot(
            index="number_of_filters",
            columns="number_of_per_atom_features",
            values="test/per_system_energy/mae",
        )
        
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        fig.suptitle(f"Number of interaction modules: {number_of_interaction_modules}; Number of radial basis functions: {number_of_radial_basis_functions}")
        sns.heatmap(
            ax=axes[0],
            data=mean_heatmap_df,
            annot=True, 
            fmt=".3f",
            cmap='OrRd',
            vmin=1,
            vmax=8,
        )
        axes[0].set_title("Test energy MAE mean (kJ/mol)")
        sns.heatmap(
            ax=axes[1],
            data=std_heatmap_df,
            annot=True, 
            fmt=".2f",
            cmap='GnBu',
            vmin=0,
            vmax=3,
        )
        axes[1].set_title("Test energy MAE standard deviation (kJ/mol)")

# %%
for number_of_per_atom_features in [32, 64, 128, 256, 512]:
    for number_of_filters in [32, 64, 128, 256, 512]:
        mean_heatmap_df = test_results_df[(test_results_df["number_of_per_atom_features"] == number_of_per_atom_features) & (test_results_df["number_of_filters"] == number_of_filters)][["number_of_interaction_modules", "number_of_radial_basis_functions", "test/per_system_energy/mae"]].groupby(["number_of_radial_basis_functions", "number_of_interaction_modules"]).agg("mean").reset_index()
        std_heatmap_df = test_results_df[(test_results_df["number_of_per_atom_features"] == number_of_per_atom_features) & (test_results_df["number_of_filters"] == number_of_filters)][["number_of_interaction_modules", "number_of_radial_basis_functions", "test/per_system_energy/mae"]].groupby(["number_of_radial_basis_functions", "number_of_interaction_modules"]).agg("std").reset_index()
        mean_heatmap_df = mean_heatmap_df.pivot(
            index="number_of_radial_basis_functions",
            columns="number_of_interaction_modules",
            values="test/per_system_energy/mae",
        )
        std_heatmap_df = std_heatmap_df.pivot(
            index="number_of_radial_basis_functions",
            columns="number_of_interaction_modules",
            values="test/per_system_energy/mae",
        )
        
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        fig.suptitle(f"Number of per atom features: {number_of_per_atom_features}; Number of filters: {number_of_filters}")
        sns.heatmap(
            ax=axes[0],
            data=mean_heatmap_df,
            annot=True, 
            fmt=".3f",
            cmap='OrRd',
            vmin=1,
            vmax=8,
        )
        axes[0].set_title("Test energy MAE mean (kJ/mol)")
        sns.heatmap(
            ax=axes[1],
            data=std_heatmap_df,
            annot=True, 
            fmt=".2f",
            cmap='GnBu',
            vmin=0,
            vmax=3,
        )
        axes[1].set_title("Test energy MAE standard deviation (kJ/mol)")
# Out:
# /var/folders/7w/svn2b6t10zxbc26rffd69qpc0000gp/T/ipykernel_31282/1909958792.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# %% [markdown]
# ### Statistical analysis

# %%
test_results_df[['number_of_radial_basis_functions','number_of_interaction_modules','number_of_filters','number_of_per_atom_features','test/per_system_energy/mae']].corr(    
)['test/per_system_energy/mae'].drop(
    'test/per_system_energy/mae'
).sort_values(
    key=abs,
    ascending=False,
)
# Out:
# number_of_interaction_modules      -0.667515
# number_of_per_atom_features        -0.290986
# number_of_filters                  -0.228771
# number_of_radial_basis_functions   -0.090138
# Name: test/per_system_energy/mae, dtype: float64
